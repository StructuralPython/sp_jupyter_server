# %%
import forallpeople
import handcalcs.render
forallpeople.environment('structural', top_level=True)
# from rjc.jupyter import title_block

# %%
# title_block("Seymour Estates Site 1", "VAN.116795.0003", "CMF", Member="Retaining Wall Gap +ve Moment")

# %% [markdown]
# # Concrete Flexural Resistance  - $M_f$ given
#
# For simple checks on concrete flexural resistance

# %%
## Inputs
M_f = 189*kN*m
h_c = 12*inch
b = 2.5*m
cover = 3*inch

phi_c = 0.65
f_c = 35*MPa
f_y = 400*MPa

# %% [markdown]
# ## Section parameters

# %%
# %%render params
# b
# cover
# phi_c
# f_c
# f_y
# Out:
# $$
# \begin{aligned}
# b &= 2.500\ \mathrm{m} \;
#  &\mathrm{cover} &= 3.000\ \mathrm{inch} \;
#  &\phi_{c} &= 0.650 \;
# \\
#  f_{c} &= 35.000\ \mathrm{MPa} \;
#  &f_{y} &= 400.000\ \mathrm{MPa} \;
# \end{aligned}
# $$

# %% [markdown]
# ## Factored Moment

# %%
# %%render params
# M_f
# Out:
# $$
# \begin{aligned}
# M_{f} &= 189.000\ \mathrm{kN} \cdot \mathrm{m} \;
# \end{aligned}
# $$

# %% [markdown]
# ## Flexural Resistance

# %%
# %%render
# # Long
# d = min(0.9*(h_c), h_c-cover-20*mm/2)
# Out:
# $$
# \begin{aligned}
# d &= \operatorname{min} \left( 0.9 \cdot h_{c} ,\  h_{c} - \mathrm{cover} - 20 \cdot \frac{ \mathrm{mm} }{ 2 } \right) \\&= \operatorname{min} \left( 0.9 \cdot 12.000\ \mathrm{inch} ,\  12.000\ \mathrm{inch} - 3.000\ \mathrm{inch} - 20 \cdot \frac{ mm }{ 2 } \right) \\&= 8.606\ \mathrm{inch}  \\
# \end{aligned}
# $$

# %%
def sqrt(x):
    if hasattr(x, "dimensions") and x.dimensions == (1, -1, -2, 0, 0, 0, 0):
        return float(x)**0.5 * MPa
    return x**0.5

# %%
# %%render
# A_s_req_400 = 0.0015/MPa*f_c*b*(d - sqrt(d**2 - (3.85*M_f)/(f_c * b)))
# Out:
# $$
# \begin{aligned}
# A_{s_{req_{400}}} &= \frac{ 0.0015 }{ \mathrm{MPa} } \cdot f_{c} \cdot b \cdot \left( d - \sqrt { \left( d \right) ^{ 2 } - \frac{ 3.85 \cdot M_{f} }{ f_{c} \cdot b } } \right) \\&= \frac{ 0.0015 }{ MPa } \cdot 35.000\ \mathrm{MPa} \cdot 2.500\ \mathrm{m} \cdot \left( 8.606\ \mathrm{inch} - \sqrt { \left( 8.606\ \mathrm{inch} \right) ^{ 2 } - \frac{ 3.85 \cdot 189.000\ \mathrm{kN} \cdot \mathrm{m} }{ 35.000\ \mathrm{MPa} \cdot 2.500\ \mathrm{m} } } \right) \\&= 2615.749\ \mathrm{mm}^{2}  \\
# \end{aligned}
# $$

# %%
# %%render
# A_s_req_300 = 400 / 300 * A_s_req_400
# Out:
# $$
# \begin{aligned}
# A_{s_{req_{300}}} &= \frac{ 400 }{ 300 } \cdot A_{s_{req_{400}}}  = \frac{ 400 }{ 300 } \cdot 2615.749\ \mathrm{mm}^{2} &= 3487.666\ \mathrm{mm}^{2}
# \end{aligned}
# $$
